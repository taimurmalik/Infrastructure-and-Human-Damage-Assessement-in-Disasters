# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import os
import glob
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, Callback
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.utils import class_weight

# ✅ Install tensorflow-addons (run this in a separate Kaggle cell if needed)
# !pip install tensorflow-addons

try:
    import tensorflow_addons as tfa
    tfa_available = True
except ImportError:
    print("⚠ tensorflow-addons not available. Falling back to Adam optimizer and skipping random_cutout.")
    tfa_available = False

# ✅ Custom Cutout Implementation
def custom_cutout(image):
    if not tfa_available:
        return image
    h, w = image.shape[:2]
    mask_size = tf.random.uniform([], 0.1, 0.3, dtype=tf.float32) * tf.cast(tf.minimum(h, w), tf.float32)
    mask_size = tf.cast(mask_size, tf.int32)
    cx = tf.random.uniform([], 0, tf.cast(w, tf.float32), dtype=tf.float32)
    cy = tf.random.uniform([], 0, tf.cast(h, tf.float32), dtype=tf.float32)
    cx = tf.cast(cx, tf.int32)
    cy = tf.cast(cy, tf.int32)
    x1 = tf.clip_by_value(cx - mask_size // 2, 0, w)
    x2 = tf.clip_by_value(cx + mask_size // 2, 0, w)
    y1 = tf.clip_by_value(cy - mask_size // 2, 0, h)
    y2 = tf.clip_by_value(cy + mask_size // 2, 0, h)
    mask = tf.ones([h, w, 3])
    mask = tf.tensor_scatter_nd_update(
        mask,
        tf.stack([tf.range(y1, y2), tf.range(x1, x2)], axis=1),
        tf.zeros([(y2 - y1) * (x2 - x1) * 3])
    )
    return image * mask

# ✅ GPU Setup
print("\n✅ TensorFlow version:", tf.__version__)
print("✅ GPU device name:", tf.config.list_physical_devices('GPU'))
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    for gpu in physical_devices:
        tf.config.experimental.set_memory_growth(gpu, True)
    print("✅ Using GPU(s):", [gpu.name for gpu in physical_devices])
else:
    print("⚠ Using CPU")

# ✅ Load CSV file for remapping
csv_path = "/kaggle/input/kmapping-csv/converted_labels.csv"
print("Contents of /kaggle/input/kmapping-csv:")
print(os.listdir("/kaggle/input/kmapping-csv"))
mapping_df = pd.read_csv(csv_path)

# Debug CSV contents
print("\n✅ First 5 rows of converted_labels.csv:")
print(mapping_df.head())
print("\n✅ Column names:", mapping_df.columns.tolist())
print("\n✅ Unique image_id count:", mapping_df['image_id'].nunique())
print("\n✅ Unique image_info values:", mapping_df['image_info'].str.lower().unique())

# ✅ Function to parse image_info
def parse_image_info(image_info):
    image_info = str(image_info).lower().strip()
    if image_info == 'damage':
        return '1'  # Damage
    elif image_info == 'non-damage':
        return '0'  # Non-Damage
    else:
        return None  # Unknown, will be filtered out

# ✅ Create damage mapping
mapping_df['class'] = mapping_df['image_info'].apply(parse_image_info)
print("\n✅ Parsed class distribution:")
print(mapping_df['class'].value_counts(dropna=False))
invalid_info = mapping_df[mapping_df['class'].isnull()][['image_id', 'image_info']]
if not invalid_info.empty:
    print("\n✅ Invalid image_info entries:")
    print(invalid_info.head())
    invalid_info.to_csv(os.path.join('/kaggle/working/', 'invalid_image_info.csv'), index=False)
mapping_df = mapping_df[mapping_df['class'].notnull()]
damage_mapping = dict(zip(mapping_df['image_id'], mapping_df['class']))
print(f"\n✅ Damage mapping created with {len(damage_mapping)} entries")

# ✅ Utility function: Create DataFrame for train or test
def create_dataframe(data_dir, mapping, split='train'):
    filepaths = []
    labels = []
    missing_images = []
    print(f"\nScanning {split} directory: {data_dir}")
    split_path = os.path.join(data_dir, split)
    for disaster_name in os.listdir(split_path):
        folder_path = os.path.join(split_path, disaster_name)
        if not os.path.isdir(folder_path):
            continue
        print(f"Checking folder: {folder_path}")
        files = glob.glob(os.path.join(folder_path, '*.[jJ][pP][gG]')) + \
                glob.glob(os.path.join(folder_path, '*.[jJ][pP][eE][gG]')) + \
                glob.glob(os.path.join(folder_path, '*.[pP][nN][gG]'))
        print(f"Found {len(files)} images in {disaster_name}")
        if len(files) == 0:
            all_files = glob.glob(os.path.join(folder_path, '*'))
            print(f"All files in {disaster_name}: {all_files}")
        for file in files:
            filename = os.path.basename(file)
            image_id = os.path.splitext(filename)[0]
            if image_id in mapping:
                filepaths.append(file)
                labels.append(mapping[image_id])
            else:
                print(f"Warning: No mapping found for image_id {image_id} in {file}")
                missing_images.append((image_id, file))
    missing_images_path = os.path.join('/kaggle/working/', f'missing_images_{split}.txt')
    with open(missing_images_path, 'w') as f:
        for image_id, file in missing_images:
            f.write(f"{image_id},{file}\n")
    print(f"✅ Total images skipped in {split}: {len(missing_images)}")
    df = pd.DataFrame({'filename': filepaths, 'class': labels})
    return df

# ✅ Data Paths
base_path = "/kaggle/working/"
input_data_path = "/kaggle/input/split-data/content/split_data/"
os.makedirs(base_path, exist_ok=True)

# ✅ Debug Directory Contents
print("\nContents of /kaggle/input/split-data/content/split_data/:")
for item in os.listdir(input_data_path):
    item_path = os.path.join(input_data_path, item)
    if os.path.isdir(item_path):
        num_files = len(glob.glob(os.path.join(item_path, '*')))
        print(f"Directory: {item} ({num_files} files)")
        for sub_item in os.listdir(item_path):
            sub_item_path = os.path.join(item_path, sub_item)
            if os.path.isdir(sub_item_path):
                num_sub_files = len(glob.glob(os.path.join(sub_item_path, '*')))
                print(f"  Subdirectory: {sub_item} ({num_sub_files} files)")
    else:
        print(f"File: {item}")

# ✅ Remove hidden files
os.system("find /kaggle/input/split-data/ -name '.*' -delete")

# ✅ Create Train and Test DataFrames (80/20 split assumed in dataset)
train_df = create_dataframe(input_data_path, damage_mapping, split='train')
test_df = create_dataframe(input_data_path, damage_mapping, split='test')

print("\nTraining DataFrame distribution:")
print(train_df['class'].value_counts())
print("\nTest DataFrame distribution:")
print(test_df['class'].value_counts())

# Check if DataFrames are empty
if train_df.empty or test_df.empty:
    raise ValueError(
        "One or both DataFrames are empty. Please check the following:\n"
        "1. The dataset path '/kaggle/input/split-data/content/split_data/' contains 'train' and 'test' subfolders.\n"
        "2. The CSV file contains valid image_id and image_info entries ('damage' or 'non-damage').\n"
        "3. The image_id in the CSV matches the filenames in the dataset.\n"
        "4. The dataset is correctly uploaded to Kaggle under '/kaggle/input/split-data/content/split_data/'.\n"
        "5. The folder structure is: /kaggle/input/split-data/content/split_data/[train|test]/<disaster_name>/*.jpg (or .jpeg, .png).\n"
        "6. Check '/kaggle/working/missing_images_{split}.txt' for unmapped images."
    )

# ✅ Oversample minority class
minority_class = '0' if (train_df['class'] == '0').sum() < (train_df['class'] == '1').sum() else '1'
minority_df = train_df[train_df['class'] == minority_class]
oversampled_df = minority_df.sample(n=int(0.2 * len(minority_df)), replace=True, random_state=42)
train_df = pd.concat([train_df, oversampled_df]).sample(frac=1, random_state=42).reset_index(drop=True)
print("\nOversampled Training DataFrame distribution:")
print(train_df['class'].value_counts())

# ✅ Compute Class Weights
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_df['class'].astype(int)),
    y=train_df['class'].astype(int)
)
class_weight_dict = dict(enumerate(class_weights))
print("\n✅ Class weights:", class_weight_dict)

# ✅ Create Data Generators
IMG_SIZE = (224, 224)
BATCH_SIZE = 16

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=45,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.4,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.5, 1.5],
    channel_shift_range=20.0,
    fill_mode='nearest',
    preprocessing_function=custom_cutout if tfa_available else None
)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    train_df,
    x_col='filename',
    y_col='class',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=True,
    classes=['0', '1']
)

test_generator = test_datagen.flow_from_dataframe(
    test_df,
    x_col='filename',
    y_col='class',
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=False,
    classes=['0', '1']
)

# ✅ Build VGG16-based model
base_model = VGG16(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
base_model.trainable = True
for layer in base_model.layers[:-8]:  # Fine-tune last 8 layers
    layer.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = Dropout(0.5)(x)
output = Dense(1, activation='sigmoid')(x)
model = Model(inputs=base_model.input, outputs=output)

# ✅ Model Summary
model.summary()

# ✅ Cosine Decay Learning Rate Schedule
initial_learning_rate = 0.0001
lr_schedule = tf.keras.optimizers.schedules.CosineDecay(
    initial_learning_rate, decay_steps=30 * len(train_generator), alpha=1e-6
)

# ✅ Compile with Ranger optimizer or Adam fallback
if tfa_available:
    optimizer = tfa.optimizers.RectifiedAdam(learning_rate=lr_schedule)
    optimizer = tfa.optimizers.Lookahead(optimizer)
else:
    optimizer = Adam(learning_rate=lr_schedule)
model.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

# ✅ Callbacks
early_stop = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)

class BestTestF1ModelSaver(Callback):
    def __init__(self, test_data, save_path=os.path.join(base_path, 'best_test_f1_model.keras')):
        super(BestTestF1ModelSaver, self).__init__()
        self.test_data = test_data
        self.best_test_f1 = 0.0
        self.save_path = save_path
        self.best_epoch = 0
        self.best_metrics = {}

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        train_loss = logs.get('loss', 0.0)
        train_acc = logs.get('accuracy', 0.0)

        # Evaluate on test set
        self.test_data.reset()
        y_true_test = self.test_data.classes
        y_pred_test = self.model.predict(self.test_data, verbose=0)
        y_pred_test_classes = (y_pred_test > 0.5).astype(int).reshape(-1)

        # Compute test metrics
        test_loss, test_acc = self.model.evaluate(self.test_data, verbose=0)
        test_prec = precision_score(y_true_test, y_pred_test_classes)
        test_rec = recall_score(y_true_test, y_pred_test_classes)
        test_f1 = f1_score(y_true_test, y_pred_test_classes)

        # Print metrics for current epoch
        print(f"\nEpoch {epoch+1}")
        print(f"Train - Loss: {train_loss:.4f}, Acc: {train_acc:.4f}")
        print(f"Test  - Loss: {test_loss:.4f}, Acc: {test_acc:.4f}, Prec: {test_prec:.4f}, Rec: {test_rec:.4f}, F1: {test_f1:.4f}")

        # Save model and metrics if test F1 improves
        if test_f1 > self.best_test_f1:
            print(f"Saving model with improved TEST F1: {test_f1:.4f}")
            self.best_test_f1 = test_f1
            self.best_epoch = epoch + 1
            self.best_metrics = {
                'train_loss': train_loss,
                'train_acc': train_acc,
                'test_loss': test_loss,
                'test_acc': test_acc,
                'test_prec': test_prec,
                'test_rec': test_rec,
                'test_f1': test_f1
            }
            self.model.save(self.save_path)

    def on_train_end(self, logs=None):
        print(f"\nFinal Result - Best Epoch: {self.best_epoch}")
        print("Best Test Metrics:")
        print(f"Accuracy: {self.best_metrics['test_acc']:.4f}")
        print(f"Precision: {self.best_metrics['test_prec']:.4f}")
        print(f"Recall: {self.best_metrics['test_rec']:.4f}")
        print(f"F1 Score: {self.best_metrics['test_f1']:.4f}")
        print(f"(Train - Loss: {self.best_metrics['train_loss']:.4f}, Acc: {self.best_metrics['train_acc']:.4f})")
        print(f"(Test Loss: {self.best_metrics['test_loss']:.4f})")

# ✅ Train the model
history = model.fit(
    train_generator,
    epochs=20,
    class_weight=class_weight_dict,
    callbacks=[early_stop, BestTestF1ModelSaver(test_generator)],
    verbose=1
)

# ✅ Save Final Model
final_model_path = os.path.join(base_path, "final_trained_model.keras")
model.save(final_model_path)
print(f"✅ Final model saved to: {final_model_path}")

# ✅ Evaluation on Test Set
model = load_model(os.path.join(base_path, "best_test_f1_model.keras"))
test_generator.reset()
y_true_test = test_generator.classes
y_pred_test = model.predict(test_generator, verbose=1)
y_pred_test_classes = (y_pred_test > 0.5).astype(int).reshape(-1)

cm = confusion_matrix(y_true_test, y_pred_test_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Non-Damage', 'Damage'], yticklabels=['Non-Damage', 'Damage'])
plt.title('Confusion Matrix (Best Epoch - Test Set)')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.savefig(os.path.join(base_path, 'confusion_matrix.png'))

test_acc = accuracy_score(y_true_test, y_pred_test_classes)
test_prec = precision_score(y_true_test, y_pred_test_classes)
test_rec = recall_score(y_true_test, y_pred_test_classes)
test_f1 = f1_score(y_true_test, y_pred_test_classes)

print("\n✅ Test Set Evaluation (Best Epoch Confirmation):")
print(f"Accuracy: {test_acc:.4f} | Precision: {test_prec:.4f} | Recall: {test_rec:.4f} | F1 Score: {test_f1:.4f}")
print("\n🧾 Classification Report (Test):")
print(classification_report(y_true_test, y_pred_test_classes, target_names=['Non-Damage', 'Damage']))

# ✅ Visualize Metrics
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.savefig(os.path.join(base_path, 'training_metrics.png'))

# ✅ Visualize Misclassified Images
misclassified_idx = np.where(y_true_test != y_pred_test_classes)[0]
if len(misclassified_idx) > 0:
    print("\n✅ Visualizing 5 misclassified images:")
    plt.figure(figsize=(15, 3))
    for i, idx in enumerate(misclassified_idx[:5]):
        img_path = test_df.iloc[idx]['filename']
        img = load_img(img_path, target_size=(224, 224))
        plt.subplot(1, 5, i+1)
        plt.imshow(img)
        plt.title(f"True: {y_true_test[idx]}, Pred: {y_pred_test_classes[idx]}")
        plt.axis('off')
    plt.savefig(os.path.join(base_path, 'misclassified_images.png'))
# Out:
# ⚠ tensorflow-addons not available. Falling back to Adam optimizer and skipping random_cutout.
#
# ✅ TensorFlow version: 2.18.0
# ✅ GPU device name: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ✅ Using GPU(s): ['/physical_device:GPU:0']
# Contents of /kaggle/input/kmapping-csv:
# ['converted_labels.csv']
#
# ✅ First 5 rows of converted_labels.csv:
#        tweet_id              image_id   text_info  text_info_conf  image_info  \
# 0  9.300000e+17  929989361453621249_0      damage          1.0000      damage
# 1  9.300000e+17  929989388863508480_0  non-damage          0.7535  non-damage
# 2  9.300000e+17  929989414826024960_0      damage          1.0000  non-damage
# 3  9.300000e+17  929989443913691136_0      damage          1.0000      damage
# 4  9.300000e+17  929989443913691136_1      damage          1.0000      damage
#
#    image_info_conf                  text_human  text_human_conf  \
# 0           0.6513      injured_or_dead_people           1.0000
# 1           1.0000            not_humanitarian           0.7535
# 2           1.0000      injured_or_dead_people           1.0000
# 3           0.6031  other_relevant_information           1.0000
# 4           1.0000  other_relevant_information           1.0000
#
#                               image_human  image_human_conf image_damage  \
# 0              other_relevant_information            0.6513          NaN
# 1                        not_humanitarian            1.0000          NaN
# 2                        not_humanitarian            1.0000          NaN
# 3                  injured_or_dead_people            0.6031          NaN
# 4  rescue_volunteering_or_donation_effort            1.0000          NaN
#
#    image_damage_conf                                         tweet_text  \
# 0                NaN  RT @PressTV: UPDATE: Death toll from Iran’s qu...
# 1                NaN  RT @CAFOD: We pray for all those affected by t...
# 2                NaN  RT @ReutersWorld: JUST IN: Death toll reaches ...
# 3                NaN  RT @LaylaAlhussein: A magnitude 7.2 earthquake...
# 4                NaN  RT @LaylaAlhussein: A magnitude 7.2 earthquake...
#
#                                         image_url  \
# 0  http://pbs.twimg.com/media/DOfT-eRWkAAJ_kB.jpg
# 1  http://pbs.twimg.com/media/DOftf6AW0AAzjkE.jpg
# 2  http://pbs.twimg.com/media/DOf76fBUMAAqpv_.jpg
# 3  http://pbs.twimg.com/media/DOeoQ75XUAEpZwN.jpg
# 4  http://pbs.twimg.com/media/DOeoQ75WAAIsov_.jpg
#
#                                           image_path
# 0  data_image/iraq_iran_earthquake/13_11_2017/929...
# 1  data_image/iraq_iran_earthquake/13_11_2017/929...
# 2  data_image/iraq_iran_earthquake/13_11_2017/929...
# 3  data_image/iraq_iran_earthquake/13_11_2017/929...
# 4  data_image/iraq_iran_earthquake/13_11_2017/929...
#
# ✅ Column names: ['tweet_id', 'image_id', 'text_info', 'text_info_conf', 'image_info', 'image_info_conf', 'text_human', 'text_human_conf', 'image_human', 'image_human_conf', 'image_damage', 'image_damage_conf', 'tweet_text', 'image_url', 'image_path']
#
# ✅ Unique image_id count: 18082
#
# ✅ Unique image_info values: ['damage' 'non-damage']
#
# ✅ Parsed class distribution:
# class
# 1    9374
# 0    8708
# Name: count, dtype: int64
#
# ✅ Damage mapping created with 18082 entries
#
# Contents of /kaggle/input/split-data/content/split_data/:
# Directory: test (7 files)
#   Subdirectory: srilanka_floods (186 files)
#   Subdirectory: iraq_iran_earthquake (108 files)
#   Subdirectory: Hurricane_Harvey (847 files)
#   Subdirectory: Hurricane_Maria (862 files)
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#   Subdirectory: Hurricane_Irma (861 files)
#   Subdirectory: California_Wildfires (309 files)
#   Subdirectory: mexico_earthquake (256 files)
# Directory: train (7 files)
#   Subdirectory: srilanka_floods (742 files)
#   Subdirectory: iraq_iran_earthquake (435 files)
#   Subdirectory: Hurricane_Harvey (3386 files)
#   Subdirectory: Hurricane_Maria (3447 files)
#   Subdirectory: Hurricane_Irma (3446 files)
#   Subdirectory: California_Wildfires (1235 files)
#   Subdirectory: mexico_earthquake (1024 files)
#
# Scanning train directory: /kaggle/input/split-data/content/split_data/
# Checking folder: /kaggle/input/split-data/content/split_data/train/srilanka_floods
# Found 742 images in srilanka_floods
# Warning: No mapping found for image_id 879374567487221761_0 in /kaggle/input/split-data/content/split_data/train/srilanka_floods/879374567487221761_0.jpg
# Checking folder: /kaggle/input/split-data/content/split_data/train/iraq_iran_earthquake
# Found 435 images in iraq_iran_earthquake
# Checking folder: /kaggle/input/split-data/content/split_data/train/Hurricane_Harvey
# Found 3386 images in Hurricane_Harvey
# Warning: No mapping found for image_id 907621182538764289_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Harvey/907621182538764289_0.jpg
# Warning: No mapping found for image_id 905164228327288834_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Harvey/905164228327288834_0.jpg
# Warning: No mapping found for image_id 901650622277144576_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Harvey/901650622277144576_0.jpg
# Warning: No mapping found for image_id 907413207115091970_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Harvey/907413207115091970_0.jpg
# Warning: No mapping found for image_id 905015318401216512_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Harvey/905015318401216512_1.jpg
# Warning: No mapping found for image_id 908344663698001922_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Harvey/908344663698001922_1.jpg
# Warning: No mapping found for image_id 908822060771823616_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Harvey/908822060771823616_0.jpg
# Warning: No mapping found for image_id 906696876090675201_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Harvey/906696876090675201_1.jpg
# Warning: No mapping found for image_id 908772392159387648_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Harvey/908772392159387648_0.jpg
# Warning: No mapping found for image_id 908702885202075650_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Harvey/908702885202075650_1.jpg
# Warning: No mapping found for image_id 905835830824116224_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Harvey/905835830824116224_0.jpg
# Warning: No mapping found for image_id 906984195439788032_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Harvey/906984195439788032_0.jpg
# Warning: No mapping found for image_id 906983861489422339_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Harvey/906983861489422339_0.jpg
# Warning: No mapping found for image_id 905777977249681409_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Harvey/905777977249681409_1.jpg
# Warning: No mapping found for image_id 901688029521334272_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Harvey/901688029521334272_0.jpg
# Warning: No mapping found for image_id 909977356546318336_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Harvey/909977356546318336_1.jpg
# Checking folder: /kaggle/input/split-data/content/split_data/train/Hurricane_Maria
# Found 3447 images in Hurricane_Maria
# Warning: No mapping found for image_id 922982238207299585_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/922982238207299585_0.jpg
# Warning: No mapping found for image_id 914701520066813952_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/914701520066813952_0.jpg
# Warning: No mapping found for image_id 912056259142176768_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/912056259142176768_0.jpg
# Warning: No mapping found for image_id 927339068672880640_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/927339068672880640_0.jpg
# Warning: No mapping found for image_id 911753146757795842_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/911753146757795842_1.jpg
# Warning: No mapping found for image_id 911502698310246400_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/911502698310246400_1.jpg
# Warning: No mapping found for image_id 910558451067117568_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/910558451067117568_1.jpg
# Warning: No mapping found for image_id 912049613812715521_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/912049613812715521_0.jpg
# Warning: No mapping found for image_id 914901016927186948_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/914901016927186948_0.jpg
# Warning: No mapping found for image_id 929459592618172416_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/929459592618172416_0.jpg
# Warning: No mapping found for image_id 922539455847780353_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/922539455847780353_1.jpg
# Warning: No mapping found for image_id 927330578634067968_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/927330578634067968_0.jpg
# Warning: No mapping found for image_id 914540213875200000_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/914540213875200000_1.jpg
# Warning: No mapping found for image_id 914540213875200000_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/914540213875200000_0.jpg
# Warning: No mapping found for image_id 913594815408984065_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/913594815408984065_1.jpg
# Warning: No mapping found for image_id 915282034628730884_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/915282034628730884_1.jpg
# Warning: No mapping found for image_id 929375602414620672_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/929375602414620672_0.jpg
# Warning: No mapping found for image_id 916027872212656129_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/916027872212656129_1.jpg
# Warning: No mapping found for image_id 921755152075444225_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/921755152075444225_0.jpg
# Warning: No mapping found for image_id 929456086737854464_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/929456086737854464_0.jpg
# Warning: No mapping found for image_id 922588041952182272_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/922588041952182272_1.jpg
# Warning: No mapping found for image_id 915196935245615105_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/915196935245615105_0.jpg
# Warning: No mapping found for image_id 923330167375663104_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/923330167375663104_0.jpg
# Warning: No mapping found for image_id 911984028630306816_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/911984028630306816_1.jpg
# Warning: No mapping found for image_id 910794095273984000_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Maria/910794095273984000_1.jpg
# Checking folder: /kaggle/input/split-data/content/split_data/train/Hurricane_Irma
# Found 3446 images in Hurricane_Irma
# Warning: No mapping found for image_id 909415207868309505_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Irma/909415207868309505_1.jpg
# Warning: No mapping found for image_id 910212147405217792_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Irma/910212147405217792_0.jpg
# Warning: No mapping found for image_id 909811330814824449_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Irma/909811330814824449_0.jpg
# Warning: No mapping found for image_id 905636873921495040_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Irma/905636873921495040_1.jpg
# Warning: No mapping found for image_id 910149119544610817_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Irma/910149119544610817_0.jpg
# Warning: No mapping found for image_id 905630580745830400_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Irma/905630580745830400_0.jpg
# Warning: No mapping found for image_id 909393303052935168_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Irma/909393303052935168_0.jpg
# Warning: No mapping found for image_id 909822750608515072_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Irma/909822750608515072_0.jpg
# Warning: No mapping found for image_id 909399816509280256_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Irma/909399816509280256_0.jpg
# Warning: No mapping found for image_id 909822387293650945_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Irma/909822387293650945_0.jpg
# Warning: No mapping found for image_id 910149358187716608_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Irma/910149358187716608_0.jpg
# Warning: No mapping found for image_id 910149358187716608_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Irma/910149358187716608_1.jpg
# Warning: No mapping found for image_id 906927973164613632_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Irma/906927973164613632_0.jpg
# Warning: No mapping found for image_id 909781181897543680_0 in /kaggle/input/split-data/content/split_data/train/Hurricane_Irma/909781181897543680_0.jpg
# Warning: No mapping found for image_id 909968982362517504_1 in /kaggle/input/split-data/content/split_data/train/Hurricane_Irma/909968982362517504_1.jpg
# Checking folder: /kaggle/input/split-data/content/split_data/train/California_Wildfires
# Found 1235 images in California_Wildfires
# Warning: No mapping found for image_id 922217954644824064_1 in /kaggle/input/split-data/content/split_data/train/California_Wildfires/922217954644824064_1.jpg
# Warning: No mapping found for image_id 921051431368515584_1 in /kaggle/input/split-data/content/split_data/train/California_Wildfires/921051431368515584_1.jpg
# Checking folder: /kaggle/input/split-data/content/split_data/train/mexico_earthquake
# Found 1024 images in mexico_earthquake
# Warning: No mapping found for image_id 910807746236186624_1 in /kaggle/input/split-data/content/split_data/train/mexico_earthquake/910807746236186624_1.jpg
# Warning: No mapping found for image_id 910670548191010817_1 in /kaggle/input/split-data/content/split_data/train/mexico_earthquake/910670548191010817_1.jpg
# ✅ Total images skipped in train: 61
#
# Scanning test directory: /kaggle/input/split-data/content/split_data/
# Checking folder: /kaggle/input/split-data/content/split_data/test/srilanka_floods
# Found 186 images in srilanka_floods
# Checking folder: /kaggle/input/split-data/content/split_data/test/iraq_iran_earthquake
# Found 108 images in iraq_iran_earthquake
# Checking folder: /kaggle/input/split-data/content/split_data/test/Hurricane_Harvey
# Found 847 images in Hurricane_Harvey
# Warning: No mapping found for image_id 906817042808020992_0 in /kaggle/input/split-data/content/split_data/test/Hurricane_Harvey/906817042808020992_0.jpg
# Warning: No mapping found for image_id 906499211855847424_0 in /kaggle/input/split-data/content/split_data/test/Hurricane_Harvey/906499211855847424_0.jpg
# Warning: No mapping found for image_id 907817400564928513_0 in /kaggle/input/split-data/content/split_data/test/Hurricane_Harvey/907817400564928513_0.jpg
# Warning: No mapping found for image_id 904353547025883138_1 in /kaggle/input/split-data/content/split_data/test/Hurricane_Harvey/904353547025883138_1.jpg
# Warning: No mapping found for image_id 907659415268012032_0 in /kaggle/input/split-data/content/split_data/test/Hurricane_Harvey/907659415268012032_0.jpg
# Warning: No mapping found for image_id 905196162415820805_1 in /kaggle/input/split-data/content/split_data/test/Hurricane_Harvey/905196162415820805_1.jpg
# Warning: No mapping found for image_id 905863590980222976_0 in /kaggle/input/split-data/content/split_data/test/Hurricane_Harvey/905863590980222976_0.jpg
# Checking folder: /kaggle/input/split-data/content/split_data/test/Hurricane_Maria
# Found 862 images in Hurricane_Maria
# Warning: No mapping found for image_id 923365901138833409_0 in /kaggle/input/split-data/content/split_data/test/Hurricane_Maria/923365901138833409_0.jpg
# Warning: No mapping found for image_id 922765857276792838_0 in /kaggle/input/split-data/content/split_data/test/Hurricane_Maria/922765857276792838_0.jpg
# Checking folder: /kaggle/input/split-data/content/split_data/test/Hurricane_Irma
# Found 861 images in Hurricane_Irma
# Warning: No mapping found for image_id 909836596802998272_0 in /kaggle/input/split-data/content/split_data/test/Hurricane_Irma/909836596802998272_0.jpg
# Warning: No mapping found for image_id 910245288903888897_0 in /kaggle/input/split-data/content/split_data/test/Hurricane_Irma/910245288903888897_0.jpg
# Warning: No mapping found for image_id 909446416640200704_0 in /kaggle/input/split-data/content/split_data/test/Hurricane_Irma/909446416640200704_0.jpg
# Warning: No mapping found for image_id 909774149698179072_1 in /kaggle/input/split-data/content/split_data/test/Hurricane_Irma/909774149698179072_1.jpg
# Checking folder: /kaggle/input/split-data/content/split_data/test/California_Wildfires
# Found 309 images in California_Wildfires
# Checking folder: /kaggle/input/split-data/content/split_data/test/mexico_earthquake
# Found 256 images in mexico_earthquake
# ✅ Total images skipped in test: 13
#
# Training DataFrame distribution:
# class
# 1    7048
# 0    6606
# Name: count, dtype: int64
#
# Test DataFrame distribution:
# class
# 1    1767
# 0    1649
# Name: count, dtype: int64
#
# Oversampled Training DataFrame distribution:
# class
# 0    7927
# 1    7048
# Name: count, dtype: int64
#
# ✅ Class weights: {0: 0.9445565787813801, 1: 1.0623581157775255}
# Found 14975 validated image filenames belonging to 2 classes.
# Found 3416 validated image filenames belonging to 2 classes.
# I0000 00:00:1747740173.008675      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             513 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,979,905 (57.14 MB)
#  Trainable params: 13,243,393 (50.52 MB)
#  Non-trainable params: 1,736,512 (6.62 MB)
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747740180.419683      95 service.cc:148] XLA service 0x7a2100014460 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747740180.420589      95 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1747740181.036278      95 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   2/936 ━━━━━━━━━━━━━━━━━━━━ 1:11 76ms/step - accuracy: 0.4844 - loss: 6.0135
# I0000 00:00:1747740188.533150      95 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.6356 - loss: 3.9631
# Epoch 1
# Train - Loss: 2.7481, Acc: 0.6635
# Test  - Loss: 1.2859, Acc: 0.6780, Prec: 0.8318, Rec: 0.4731, F1: 0.6032
# Saving model with improved TEST F1: 0.6032
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 361s 373ms/step - accuracy: 0.6356 - loss: 3.9618
# Epoch 2/20
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.6996 - loss: 1.1141
# Epoch 2
# Train - Loss: 0.9923, Acc: 0.7012
# Test  - Loss: 0.8068, Acc: 0.7409, Prec: 0.7546, Rec: 0.7397, F1: 0.7471
# Saving model with improved TEST F1: 0.7471
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 233s 248ms/step - accuracy: 0.6996 - loss: 1.1139
# Epoch 3/20
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.7064 - loss: 0.7818
# Epoch 3
# Train - Loss: 0.7458, Acc: 0.7147
# Test  - Loss: 0.8448, Acc: 0.6528, Prec: 0.6087, Rec: 0.9208, F1: 0.7329
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 228s 244ms/step - accuracy: 0.7064 - loss: 0.7818
# Epoch 4/20
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.7193 - loss: 0.6770
# Epoch 4
# Train - Loss: 0.6661, Acc: 0.7168
# Test  - Loss: 0.5941, Acc: 0.7567, Prec: 0.7393, Rec: 0.8183, F1: 0.7768
# Saving model with improved TEST F1: 0.7768
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 230s 246ms/step - accuracy: 0.7193 - loss: 0.6770
# Epoch 5/20
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.7195 - loss: 0.6347
# Epoch 5
# Train - Loss: 0.6196, Acc: 0.7245
# Test  - Loss: 0.6061, Acc: 0.7395, Prec: 0.7069, Rec: 0.8478, F1: 0.7710
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 226s 242ms/step - accuracy: 0.7195 - loss: 0.6347
# Epoch 6/20
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.7334 - loss: 0.5872
# Epoch 6
# Train - Loss: 0.5832, Acc: 0.7333
# Test  - Loss: 0.6090, Acc: 0.6923, Prec: 0.8214, Rec: 0.5178, F1: 0.6352
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 226s 242ms/step - accuracy: 0.7334 - loss: 0.5872
# Epoch 7/20
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.7296 - loss: 0.5658
# Epoch 7
# Train - Loss: 0.5647, Acc: 0.7316
# Test  - Loss: 0.5164, Acc: 0.7597, Prec: 0.7403, Rec: 0.8246, F1: 0.7802
# Saving model with improved TEST F1: 0.7802
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 228s 243ms/step - accuracy: 0.7296 - loss: 0.5658
# Epoch 8/20
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.7255 - loss: 0.5601
# Epoch 8
# Train - Loss: 0.5503, Acc: 0.7332
# Test  - Loss: 0.5341, Acc: 0.7471, Prec: 0.7127, Rec: 0.8563, F1: 0.7779
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 233s 249ms/step - accuracy: 0.7255 - loss: 0.5601
# Epoch 9/20
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.7306 - loss: 0.5495
# Epoch 9
# Train - Loss: 0.5417, Acc: 0.7361
# Test  - Loss: 0.5004, Acc: 0.7573, Prec: 0.7489, Rec: 0.7985, F1: 0.7729
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 237s 253ms/step - accuracy: 0.7306 - loss: 0.5495
# Epoch 10/20
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.7451 - loss: 0.5358
# Epoch 10
# Train - Loss: 0.5326, Acc: 0.7470
# Test  - Loss: 0.5031, Acc: 0.7676, Prec: 0.7431, Rec: 0.8415, F1: 0.7893
# Saving model with improved TEST F1: 0.7893
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 239s 255ms/step - accuracy: 0.7451 - loss: 0.5358
# Epoch 11/20
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.7543 - loss: 0.5224
# Epoch 11
# Train - Loss: 0.5256, Acc: 0.7505
# Test  - Loss: 0.5551, Acc: 0.7491, Prec: 0.7087, Rec: 0.8744, F1: 0.7829
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 239s 255ms/step - accuracy: 0.7543 - loss: 0.5224
# Epoch 12/20
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.7480 - loss: 0.5243
# Epoch 12
# Train - Loss: 0.5210, Acc: 0.7521
# Test  - Loss: 0.5892, Acc: 0.7389, Prec: 0.6834, Rec: 0.9225, F1: 0.7852
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 239s 256ms/step - accuracy: 0.7480 - loss: 0.5243
# Epoch 13/20
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.7488 - loss: 0.5154
# Epoch 13
# Train - Loss: 0.5122, Acc: 0.7513
# Test  - Loss: 0.5026, Acc: 0.7635, Prec: 0.7345, Rec: 0.8500, F1: 0.7880
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 239s 255ms/step - accuracy: 0.7488 - loss: 0.5154
# Epoch 14/20
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.7598 - loss: 0.5022
# Epoch 14
# Train - Loss: 0.5027, Acc: 0.7589
# Test  - Loss: 0.5150, Acc: 0.7520, Prec: 0.7195, Rec: 0.8534, F1: 0.7807
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 239s 255ms/step - accuracy: 0.7598 - loss: 0.5022
# Epoch 15/20
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.7558 - loss: 0.4976
# Epoch 15
# Train - Loss: 0.5017, Acc: 0.7574
# Test  - Loss: 0.4883, Acc: 0.7617, Prec: 0.8372, Rec: 0.6695, F1: 0.7440
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 241s 257ms/step - accuracy: 0.7558 - loss: 0.4976
# Epoch 16/20
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.7639 - loss: 0.4904
# Epoch 16
# Train - Loss: 0.4950, Acc: 0.7624
# Test  - Loss: 0.6964, Acc: 0.7260, Prec: 0.6778, Rec: 0.8964, F1: 0.7719
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 233s 249ms/step - accuracy: 0.7639 - loss: 0.4904
# Epoch 17/20
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.7582 - loss: 0.4967
# Epoch 17
# Train - Loss: 0.4901, Acc: 0.7625
# Test  - Loss: 0.5584, Acc: 0.7386, Prec: 0.6844, Rec: 0.9179, F1: 0.7841
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 234s 250ms/step - accuracy: 0.7582 - loss: 0.4967
# Epoch 18/20
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.7718 - loss: 0.4823
# Epoch 18
# Train - Loss: 0.4907, Acc: 0.7654
# Test  - Loss: 0.5147, Acc: 0.7649, Prec: 0.7340, Rec: 0.8557, F1: 0.7902
# Saving model with improved TEST F1: 0.7902
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 235s 251ms/step - accuracy: 0.7718 - loss: 0.4823
# Epoch 19/20
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.7741 - loss: 0.4810
# Epoch 19
# Train - Loss: 0.4826, Acc: 0.7733
# Test  - Loss: 0.4801, Acc: 0.7766, Prec: 0.7764, Rec: 0.7980, F1: 0.7870
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 235s 251ms/step - accuracy: 0.7741 - loss: 0.4810
# Epoch 20/20
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.7691 - loss: 0.4853
# Epoch 20
# Train - Loss: 0.4758, Acc: 0.7750
# Test  - Loss: 0.5117, Acc: 0.7673, Prec: 0.7301, Rec: 0.8727, F1: 0.7951
# Saving model with improved TEST F1: 0.7951
# 936/936 ━━━━━━━━━━━━━━━━━━━━ 235s 251ms/step - accuracy: 0.7691 - loss: 0.4853
#
# Final Result - Best Epoch: 20
# Best Test Metrics:
# Accuracy: 0.7673
# Precision: 0.7301
# Recall: 0.8727
# F1 Score: 0.7951
# (Train - Loss: 0.4758, Acc: 0.7750)
# (Test Loss: 0.5117)
# ✅ Final model saved to: /kaggle/working/final_trained_model.keras
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step
#
# ✅ Test Set Evaluation (Best Epoch Confirmation):
# Accuracy: 0.7673 | Precision: 0.7301 | Recall: 0.8727 | F1 Score: 0.7951
#
# 🧾 Classification Report (Test):
#               precision    recall  f1-score   support
#
#   Non-Damage       0.83      0.65      0.73      1649
#       Damage       0.73      0.87      0.80      1767
#
#     accuracy                           0.77      3416
#    macro avg       0.78      0.76      0.76      3416
# weighted avg       0.78      0.77      0.76      3416
#
#
# ✅ Visualizing 5 misclassified images:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_35/2363518500.py in <cell line: 0>()
#     391     for i, idx in enumerate(misclassified_idx[:5]):
#     392         img_path = test_df.iloc[idx]['filename']
# --> 393         img = load_img(img_path, target_size=(224, 224))
#     394         plt.subplot(1, 5, i+1)
#     395         plt.imshow(img)
#
# NameError: name 'load_img' is not defined
